# %% [markdown]
# Notebook to test scrapping

# %%
# Option A: BeautifulSoup + Selenium (flexible, lightweight)
from bs4 import BeautifulSoup
import selenium

# Option B: Scrapy (pour scraping à grande échelle)
import scrapy

# Option C: LLM-friendly: Use Firecrawl or Jina AI Reader
# (extracte le contenu principal sans HTML noise)
